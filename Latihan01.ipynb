# %% [markdown]
# Cara menghitung detik dalam 1 hari:

# %%
jumlahDetikDalam1Hari = 24 * 60 * 60
jumlahDetikDalam1hari

# %%
nama_mhs1 = "Putri Ramadina Daulay"
nama_mhs2 = "Dara Novtah Eka Sukma"
print(nama_mhs1, "dan", nama_mhs2, "adalah mahasiswa TRKJ\nFakultas Teknologi Industri, Universitas Bung Hatta")
# Out:
# Putri Ramadina Daulay dan Dara Novtah Eka Sukma adalah mahasiswa TRKJ
# Fakultas Teknologi Industri, Universitas Bung Hatta
